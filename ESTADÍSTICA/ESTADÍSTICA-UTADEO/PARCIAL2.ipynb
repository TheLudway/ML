# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('vehiculos.csv', delimiter=',', encoding='unicode_escape')

# %%
df.head()
# Out:
#             Make              Model   Price  Year  Kilometer    Fuel  \
# 0           Tata          Nano Base   490.0  2010      60000  Petrol
# 1        Hyundai            i10 Era  1300.0  2009      59000  Petrol
# 2        Hyundai         Santro GLS  1410.0  2009      56400  Petrol
# 3        Hyundai    Santro GL (CNG)  1450.0  2009      72000     CNG
# 4  Maruti Suzuki  Wagon R LXi Minor  1450.0  2009      39586  Petrol
#
#   Transmission    Location   Color   Owner      Seller  Engine  \
# 0       Manual     Gurgaon   White   First  Individual     624
# 1       Manual      Kanpur  Silver  Second  Individual    1086
# 2       Manual  Jamshedpur  Silver   Third  Individual    1086
# 3       Manual      Kanpur  Silver  Second  Individual    1086
# 4       Manual      Ranchi     Red   First  Individual    1061
#
#                Power            Torque Drivetrain  Length  Width  Height  \
# 0            35@5250           48@3000        RWD    3099   1495    1652
# ...

# %% [markdown]
# # Ejercicio 1
# ## Con respecto a la longitud del carro y la capacidad del tanque es FALSO que:

# %%
dato1 = df['Length'].to_numpy()
dato2 = df['Tank'].to_numpy()

plt.boxplot([dato1], labels=['Longitud'])
plt.xlabel('Variables')
plt.ylabel('Valores')
plt.title('Diagrama de caja')
plt.show()

# %%
plt.boxplot([dato2], labels=['Capacidad Tanque'])
plt.show()

# %%
df.describe()
# Out:
#                Price         Year     Kilometer       Engine       Length  \
# count    1874.000000  1874.000000  1.874000e+03  1874.000000  1874.000000
# mean    17182.790368  2016.713447  5.317814e+04  1682.829242  4281.512807
# std     24260.903507     3.138477  5.878833e+04   633.055721   436.220747
# min       490.000000  1988.000000  0.000000e+00   624.000000  3099.000000
# 25%      5000.000000  2015.000000  2.801975e+04  1197.000000  3985.000000
# 50%      8424.995000  2017.000000  4.879750e+04  1497.000000  4360.000000
# 75%     19082.500000  2019.000000  7.100000e+04  1995.000000  4620.000000
# max    350000.000000  2022.000000  2.000000e+06  6592.000000  5569.000000
#
#              Width       Height        Seats         Tank
# count  1874.000000  1874.000000  1874.000000  1874.000000
# mean   1767.886339  1588.967983     5.295091    52.217343
# std     131.344883   134.627659     0.807008    15.167250
# min    1475.000000  1213.000000     2.000000    15.000000
# ...

# %%
df[df['Make'] == 'Hyundai']
# Out:
#          Make                                         Model     Price  Year  \
# 1     Hyundai                                       i10 Era   1300.00  2009
# 2     Hyundai                                    Santro GLS   1410.00  2009
# 3     Hyundai                               Santro GL (CNG)   1450.00  2009
# 5     Hyundai                                 i10 Magna (O)   1500.00  2008
# 10    Hyundai                                 i10 Magna 1.2   1650.00  2009
# ...       ...                                           ...       ...   ...
# 1427  Hyundai             Creta SX (O) 1.5 Diesel Automatic  19899.99  2022
# 1439  Hyundai                       Tucson GL 2WD AT Diesel  20899.99  2019
# 1446  Hyundai     Alcazar Signature (O) 6 STR 2.0 Petrol AT  21400.00  2021
# 1490  Hyundai                       Tucson GL 2WD AT Diesel  23950.00  2019
# 1498  Hyundai  Alcazar Signature (O) 7 Seater 1.5 Diesel AT  24000.00  2022
#
# ...

# %% [markdown]
# # Ejercicio 2
# ## Con respecto a las estadísticas básicas de los automóviles es FALSO que:

# %%
df[df['Make'] == 'Mercedes-Benz']['Price'].var(), df[df['Make'] == 'Honda']['Price'].var()
# Out:
# (1084375542.3673527, 8729226.405733895)

# %% [markdown]
# # Ejercicio 3
# ## Para los vehiculos de primer y segundo dueño es FALSO que

# %%
df[(df['Owner'] == 'First')]['Kilometer'].describe()
# Out:
# count    1.504000e+03
# mean     5.021487e+04
# std      6.343693e+04
# min      7.500000e+01
# 25%      2.520625e+04
# 50%      4.500000e+04
# 75%      6.700000e+04
# max      2.000000e+06
# Name: Kilometer, dtype: float64

# %%
plt.boxplot(df[(df['Owner'] == 'First')]['Kilometer'].to_numpy())
plt.show()

# %%
df.head()
# Out:
#             Make              Model   Price  Year  Kilometer    Fuel  \
# 0           Tata          Nano Base   490.0  2010      60000  Petrol
# 1        Hyundai            i10 Era  1300.0  2009      59000  Petrol
# 2        Hyundai         Santro GLS  1410.0  2009      56400  Petrol
# 3        Hyundai    Santro GL (CNG)  1450.0  2009      72000     CNG
# 4  Maruti Suzuki  Wagon R LXi Minor  1450.0  2009      39586  Petrol
#
#   Transmission    Location   Color   Owner      Seller  Engine  \
# 0       Manual     Gurgaon   White   First  Individual     624
# 1       Manual      Kanpur  Silver  Second  Individual    1086
# 2       Manual  Jamshedpur  Silver   Third  Individual    1086
# 3       Manual      Kanpur  Silver  Second  Individual    1086
# 4       Manual      Ranchi     Red   First  Individual    1061
#
#                Power            Torque Drivetrain  Length  Width  Height  \
# 0            35@5250           48@3000        RWD    3099   1495    1652
# ...

# %%
correlation_matrix = df[['Price', 'Year', 'Kilometer', 'Engine', 'Length', 'Width', 'Height', 'Seats', 'Tank']].corr()
max_correlation = correlation_matrix.abs().unstack().sort_values(ascending=False)
most_correlated_variables = max_correlation[max_correlation != 1].index[0]
most_correlated_variables
# Out:
# ('Tank', 'Length')

# %%
df['Engine'].corr(df['Length'])
# Out:
# 0.7998321641563141

# %% [markdown]
# # Ejercicio 5
# ## Para el caso de los vehículos de menos 100.000 kilómetros es FALSO que:

# %%
df.head()
# Out:
#             Make              Model   Price  Year  Kilometer    Fuel  \
# 0           Tata          Nano Base   490.0  2010      60000  Petrol
# 1        Hyundai            i10 Era  1300.0  2009      59000  Petrol
# 2        Hyundai         Santro GLS  1410.0  2009      56400  Petrol
# 3        Hyundai    Santro GL (CNG)  1450.0  2009      72000     CNG
# 4  Maruti Suzuki  Wagon R LXi Minor  1450.0  2009      39586  Petrol
#
#   Transmission    Location   Color   Owner      Seller  Engine  \
# 0       Manual     Gurgaon   White   First  Individual     624
# 1       Manual      Kanpur  Silver  Second  Individual    1086
# 2       Manual  Jamshedpur  Silver   Third  Individual    1086
# 3       Manual      Kanpur  Silver  Second  Individual    1086
# 4       Manual      Ranchi     Red   First  Individual    1061
#
#                Power            Torque Drivetrain  Length  Width  Height  \
# 0            35@5250           48@3000        RWD    3099   1495    1652
# ...

# %%
df[(df['Kilometer'] < 100000)][['Price', 'Seats', 'Year', 'Kilometer', 'Engine', 'Length', 'Width', 'Height', 'Seats', 'Tank']].corr()
# Out:
#               Price     Seats      Year  Kilometer    Engine    Length  \
# Price      1.000000 -0.020014  0.303775  -0.284501  0.640087  0.584740
# Seats     -0.020014  1.000000  0.031834   0.144718  0.303762  0.279975
# Year       0.303775  0.031834  1.000000  -0.562255  0.022002  0.118108
# Kilometer -0.284501  0.144718 -0.562255   1.000000  0.022363 -0.002408
# Engine     0.640087  0.303762  0.022002   0.022363  1.000000  0.798398
# Length     0.584740  0.279975  0.118108  -0.002408  0.798398  1.000000
# Width      0.587661  0.212659  0.205643  -0.043179  0.719803  0.798781
# Height     0.099749  0.664445  0.162562   0.064553  0.318777  0.170714
# Seats     -0.020014  1.000000  0.031834   0.144718  0.303762  0.279975
# Tank       0.613885  0.280394  0.088723   0.020207  0.788937  0.808519
#
#               Width    Height     Seats      Tank
# Price      0.587661  0.099749 -0.020014  0.613885
# Seats      0.212659  0.664445  1.000000  0.280394
# ...

# %%
df[(df['Kilometer'] < 100000)]['Price'].cov(df['Tank'])
# Out:
# 227427.28234493433

# %%
help(df.corr)
# Out:
# Help on method corr in module pandas.core.frame:
#
# corr(method: 'CorrelationMethod' = 'pearson', min_periods: 'int' = 1, numeric_only: 'bool' = False) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Compute pairwise correlation of columns, excluding NA/null values.
#
#     Parameters
#     ----------
#     method : {'pearson', 'kendall', 'spearman'} or callable
#         Method of correlation:
#
#         * pearson : standard correlation coefficient
#         * kendall : Kendall Tau correlation coefficient
#         * spearman : Spearman rank correlation
#         * callable: callable with input two 1d ndarrays
#             and returning a float. Note that the returned matrix from corr
#             will have 1 along the diagonals and will be symmetric
#             regardless of the callable's behavior.
#     min_periods : int, optional
#         Minimum number of observations required per pair of columns
# ...

# %% [markdown]
# # Ejercicio 6
# ## Con respecto al número de sillas de los vehículos y su precio es FALSO que:

# %%
df[(df['Seats'] == 7)]['Make'].value_counts(normalize=True)
# Out:
# Make
# Toyota           0.311741
# Mahindra         0.246964
# Maruti Suzuki    0.117409
# Land Rover       0.052632
# Audi             0.052632
# Ford             0.048583
# Mercedes-Benz    0.044534
# Tata             0.036437
# Hyundai          0.028340
# Ssangyong        0.012146
# Mitsubishi       0.012146
# Honda            0.012146
# Isuzu            0.008097
# Datsun           0.004049
# Kia              0.004049
# Volkswagen       0.004049
# Volvo            0.004049
# Name: proportion, dtype: float64

# %%
df[(df['Seats'] == 5)]['Price'].var() > df[(df['Seats'] == 4)]['Price'].var()
# Out:
# False

# %% [markdown]
# # Ejercicio 8
# ## De los vehículos de primer dueño con trasmisión manual es FALSO que

# %%
df.head()
# Out:
#             Make              Model   Price  Year  Kilometer    Fuel  \
# 0           Tata          Nano Base   490.0  2010      60000  Petrol
# 1        Hyundai            i10 Era  1300.0  2009      59000  Petrol
# 2        Hyundai         Santro GLS  1410.0  2009      56400  Petrol
# 3        Hyundai    Santro GL (CNG)  1450.0  2009      72000     CNG
# 4  Maruti Suzuki  Wagon R LXi Minor  1450.0  2009      39586  Petrol
#
#   Transmission    Location   Color   Owner      Seller  Engine  \
# 0       Manual     Gurgaon   White   First  Individual     624
# 1       Manual      Kanpur  Silver  Second  Individual    1086
# 2       Manual  Jamshedpur  Silver   Third  Individual    1086
# 3       Manual      Kanpur  Silver  Second  Individual    1086
# 4       Manual      Ranchi     Red   First  Individual    1061
#
#                Power            Torque Drivetrain  Length  Width  Height  \
# 0            35@5250           48@3000        RWD    3099   1495    1652
# ...

# %%
df[(df['Transmission'] == 'Manual') & (df['Owner'] == 'First')]['Price'].quantile(0.95)
# Out:
# 16500.0

# %%
(df[(df['Owner'] == 'First') & (df['Transmission'] == 'Manual')]['Kilometer'].std()) / (df[(df['Owner'] == 'First') & (df['Transmission'] == 'Manual')]['Kilometer'].mean())
# Out:
# 1.4092047761533448

# %%
len(df[(df['Owner'] == 'First') & (df['Transmission'] == 'Manual')]['Make'].value_counts())
# Out:
# 17

# %% [markdown]
# # Ejercicio 9
# ## En una regresión lineal de la capacidad del tanque con base en la longitud del vehículo es FALSO que:

# %%
x = df['Length'].to_numpy().reshape(-1, 1)
y = df['Tank'].to_numpy()
modelo = LinearRegression()
modelo.fit(x, y)
print(modelo.coef_, modelo.intercept_)
# Out:
# [0.0281569] -68.33676762426447

# %%
df.head()
# Out:
#             Make              Model   Price  Year  Kilometer    Fuel  \
# 0           Tata          Nano Base   490.0  2010      60000  Petrol
# 1        Hyundai            i10 Era  1300.0  2009      59000  Petrol
# 2        Hyundai         Santro GLS  1410.0  2009      56400  Petrol
# 3        Hyundai    Santro GL (CNG)  1450.0  2009      72000     CNG
# 4  Maruti Suzuki  Wagon R LXi Minor  1450.0  2009      39586  Petrol
#
#   Transmission    Location   Color   Owner      Seller  Engine  \
# 0       Manual     Gurgaon   White   First  Individual     624
# 1       Manual      Kanpur  Silver  Second  Individual    1086
# 2       Manual  Jamshedpur  Silver   Third  Individual    1086
# 3       Manual      Kanpur  Silver  Second  Individual    1086
# 4       Manual      Ranchi     Red   First  Individual    1061
#
#                Power            Torque Drivetrain  Length  Width  Height  \
# 0            35@5250           48@3000        RWD    3099   1495    1652
# ...

# %%
4000*modelo.coef_ + modelo.intercept_
# Out:
# array([44.2908158])

# %%
modelo.score(x, y)
# Out:
# 0.6557956285232216

# %% [markdown]
# # Ejercicio 10
# ## Tome solamente los vehículos con menos de 100.000 kilómentros y construya una regresión del tamaño del motor sobre la longitud del vehículo. Con base en esto es FALSO que

# %%
df.head()
# Out:
#             Make              Model   Price  Year  Kilometer    Fuel  \
# 0           Tata          Nano Base   490.0  2010      60000  Petrol
# 1        Hyundai            i10 Era  1300.0  2009      59000  Petrol
# 2        Hyundai         Santro GLS  1410.0  2009      56400  Petrol
# 3        Hyundai    Santro GL (CNG)  1450.0  2009      72000     CNG
# 4  Maruti Suzuki  Wagon R LXi Minor  1450.0  2009      39586  Petrol
#
#   Transmission    Location   Color   Owner      Seller  Engine  \
# 0       Manual     Gurgaon   White   First  Individual     624
# 1       Manual      Kanpur  Silver  Second  Individual    1086
# 2       Manual  Jamshedpur  Silver   Third  Individual    1086
# 3       Manual      Kanpur  Silver  Second  Individual    1086
# 4       Manual      Ranchi     Red   First  Individual    1061
#
#                Power            Torque Drivetrain  Length  Width  Height  \
# 0            35@5250           48@3000        RWD    3099   1495    1652
# ...

# %%
nuevo_df = df[(df['Kilometer'] < 100000)]
X_10 = nuevo_df['Length'].to_numpy().reshape(-1, 1)
Y_10 = nuevo_df['Tank'].to_numpy()
modelo.fit(X_10, Y_10)
modelo.coef_, modelo.intercept_
# Out:
# (array([0.02746746]), -65.63805166569124)

# %%
nuevo_df['Tank'].corr(nuevo_df['Length'])
# Out:
# 0.8085192012451037

# %%
0.000000007857995 * 4000 ** 3.114895763398931
# Out:
# 1304.2269037201254

# %% [markdown]
# # **Ayuda** <br>
# 1. Tabular una variable cualitativa X:
# `df['X’].value_counts(normalize=False)`
#
# 2. Seleccionar solo las variables X, Y:
# df[['X', 'Y']]
#
# 3. Filtrar cuando la variable X es x:
# df[df['X']=='x']
#
# 4. Filtrar cuando la variable X=x & Y=y
# df[(df['X']=='x') & (df['Y']='y') ]
#
# 5. Filtrar por texto de variable:
# df[df['X'].str.contains('xxx')]
#
# 6. Ordenar por la variable X:
# df.sort_values(by=['X'],ascending=True)
#
# 7. Bloquear por una o más condiones:
# df.loc[(df['X'] == 'x') & (df['Y'] == 'y')]
#
# 8. Redondear decimales:
# round(X,1)
#
# 9. Reemplazar un símbolo para corregir typos
# df['X']=df['X'].str.replace('¥','Ñ')
#
# 10. Recodificar valores de variables
# df['X'] = df['X'].replace({'a': 'A', 'b': 'B'})
#
# 11. Group by
# df.groupby(['X','Y'])['Z'].aggregate(['count','mean','std’])
#
# 12. Crosstabulation
# pd.crosstab(df['X'], df['Y'],normalize=False)
#
# 13. Crear una tabla dinámica
# df.pivot_table(index='X',columns='Y',values='Z',aggfunc='mean')
